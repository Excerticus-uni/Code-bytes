# %%
#Plotting and adding text
mpl.rcParams['font.size']=16
plt.plot(z.real,z.imag,'ro')
plt.text(z.real,(z.imag+0.1*z.imag), 'z')
plt.plot(e.real,e.imag,'bo')
plt.text(e.real,(e.imag-0.2*e.imag), 'e')
plt.plot(f1.real,f1.imag,'ko')
plt.text(f1.real,(f1.imag+0.1*f1.imag), 'z+e')
plt.plot(f5.real,f5.imag,'go')
plt.text(f5.real,0.1, r'$e*\bar{e}$')
#Tune the plot a bit
plt.xlim(0,6);plt.ylim(-2,5)
x_label='Real';y_label='Imaginary'
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.grid();plt.show()

# %%
import math; import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
z=3+4j #Instead of i, we use j=math.sqrt(-1)
e=2-1j
f1=z+e; print(f1); f2=z*e; print(f2)
f3=z/e; print(f3);
z_conj=z.conjugate(); print(z_conj)
e_conj=e.conjugate(); print(e_conj)
f4=pow(z,-1); print(f4)
f5=e*e_conj; print(f5)
# Out:
# (5+3j)
# (10+5j)
# (0.4+2.2j)
# (3-4j)
# (2+1j)
# (0.12-0.16j)
# (5+0j)

# %%
import math
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
z=1+2j
plt.plot(z.real,z.imag,'ro',markersize=12)
#Tune the plot a bit
#Show a text next to the number:
plt.text(z.real,(z.imag+0.1*z.imag),'z')
#Set plot limits
plt.xlim(0,3);plt.ylim(0,3)
#Add axes labels and a grid
x_label='Real';y_label='Imaginary'
plt.xlabel(x_label);plt.ylabel(y_label)
plt.grid()
#Show the plot -unnecessary in a Jupyter
plt.show()
